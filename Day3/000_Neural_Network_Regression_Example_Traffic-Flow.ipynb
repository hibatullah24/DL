# %% [markdown]
# ## TODO
# https://archive.ics.uci.edu/dataset/608/traffic+flow+forecasting

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import scipy.io

# %%
mat_data = scipy.io.loadmat('./Data/traffic_dataset.mat')

# %%
mat_data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'tra_X_tr', 'tra_X_te', 'tra_Y_tr', 'tra_Y_te', 'tra_adj_mat'])
